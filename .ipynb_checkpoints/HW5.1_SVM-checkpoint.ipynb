# %% [markdown]
# # CS242 Machine Learning HW5
# ## Question 1. Support Vector Machine

# %% [markdown]
# ### Generate dataset:

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
mean1 = (1, 1)
cov1 = [[1, 0], [0, 1]]

mean2 = (-1, -1)
cov2 = [[3, 0], [0, 3]]

x_train_red = np.random.multivariate_normal(mean1, cov1, 1000)
y_train_red = np.zeros(1000)+1
x_train_blue = np.random.multivariate_normal(mean2, cov2, 1000)
y_train_blue = (np.zeros(1000)+1)*-1

x_train = np.vstack((x_train_red,x_train_blue))
x_train = np.vstack((x_train_red,x_train_blue))

x_test_red = np.random.multivariate_normal(mean1, cov1, 1000)
x_test_blue = np.random.multivariate_normal(mean2, cov2, 1000)

# %%
np.shape(x_train_blue)
# Out:
# (1000, 2)

# %%
plt.subplots(figsize=(8,8))
plt.ylabel('y')
plt.xlabel('x')
plt.scatter(x1[:,0], x1[:,1], color='red', edgecolors='black')
plt.scatter(x2[:,0], x2[:,1], color='blue', edgecolors='black')

plt.title('Figure 1. Training dataset' )
plt.show()

# %%
clf = svm.SVC(kernel='linear', C=1, gamma=0.1)
clf.fit(X, y)

# %%
# Out:
# array([  6.57688257e-01,   2.09776354e+00,   2.14891196e+00,
#          1.11962036e+00,   1.65322082e+00,   4.82967216e-01,
#         -1.08941087e-01,   1.52215297e+00,   8.31570540e-01,
#          3.38457096e-01,   7.14815785e-01,   1.62273966e-01,
#          9.14988963e-01,   2.90359332e+00,   1.26576707e+00,
#          1.09582846e+00,   8.23005910e-01,  -2.96928889e-01,
#          1.12140306e+00,   1.11844542e+00,   1.10056874e+00,
#          5.52239613e-02,   1.36897224e+00,  -7.68841699e-02,
#          4.44625094e-01,   1.57615227e+00,  -7.23127697e-01,
#          1.20613142e+00,   1.00794562e+00,   3.92426190e-01,
#          2.54114016e+00,   1.54402768e+00,   2.09155624e+00,
#          1.60186128e+00,  -4.12729284e-01,   5.94669504e-01,
#          2.01923985e+00,   3.97996190e-01,   8.96580554e-01,
#          7.73972092e-01,  -7.08227293e-01,   1.93504589e+00,
#          1.34539596e+00,  -3.63151864e-01,   2.43116945e+00,
# ...
